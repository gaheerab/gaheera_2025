# %% [raw]
# ---
# layout: post
# title: Gaheera Babbar Logic Gates
# description: Big Idea 5 Logic Gates HW Hacks
# categories: [Python]
# menu: nav/tools_setup.html
# toc: true
# comments: true
# ---

# %% [markdown]
# ## Popcorn Hack 1
# ### What are methods of real-world purpose that using logic gates can implement? Explain deeper if using our listed impacts, explaining why this impact is helpful.
#
# Logic gates are fundamental to modern technology, enabling a wide range of real-world applications like computing, data storage, control systems, communication, AI, and error detection. They are used to perform operations such as arithmetic, automate decision-making, control devices (e.g., traffic lights, smart appliances), and ensure data integrity in communication systems. By processing binary data, logic gates help create reliable, fast, and efficient systems that improve safety, productivity, and convenience across industries. Their ability to automate tasks and manage complex processes makes them essential in everything from computers to IoT devices.
#
# ## Popcorn Hack 2
# ### A digital circuit receives three binary inputs: X, Y, and Z. The circuit outputs 1 if and only if X AND Y are both 1, OR Z is 1. Which of the following expressions represents the circuit’s behavior?
#
# A. (X AND Y)

# %% [markdown]
# ## Homework Hack: Authorization System
# ### Task: Fill in the missing code necessary to implement a Python function that simulates a secure entry system using an AND gate.

# %%
def secure_entry_system(keycard, pin, voice_authorization):
    def AND(a, b, c):
        return a & b & c  # AND logic for three conditions

    return AND(keycard, pin, voice_authorization)

# Test cases
print(secure_entry_system(1, 1, 1))  # Expected Output: 1 (Access Granted)
print(secure_entry_system(0, 1, 1))  # Expected Output: 0 (Access Denied)
print(secure_entry_system(1, 0, 1))  # Expected Output: 0 (Access Denied)
print(secure_entry_system(1, 1, 0))  # Expected Output: 0 (Access Denied)
# Out:
# 1
# 0
# 0
# 0
